# %%
import pandas as pd

# %% [markdown]
# #### downloading the the avacado.csv file. <a href="https://www.kaggle.com/datasets/neuromusic/avocado-prices">avocado<a/>

# %%
pd.read_csv("avocado.csv")
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
dt=pd.read_csv("avocado.csv")

# %%
dt[dt['region'] == 'Albany']
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 17608           7  2018-02-04          1.52       4124.96   118.38     420.36
# 17609           8  2018-01-28          1.32       6987.56   433.66     374.96
# 17610           9  2018-01-21          1.54       3346.54    14.67     253.01
# 17611          10  2018-01-14          1.47       4140.95     7.30     301.87
# 17612          11  2018-01-07          1.54       4816.90    43.51     412.17
#
# ...

# %%
albany_dt =dt[dt['region'] == 'Albany']

# %%
albany_dt.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
albany_dt.set_index('Date',inplace=True)

# %%
albany_dt.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %%
albany_dt.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_dt['AveragePrice'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_dt.sort_index(inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14440\3722418117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_dt.sort_index(inplace=True)

# %%
albany_dt['AveragePrice'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_dt['AveragePrice'].rolling(25).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_dt.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
# 2015-01-11      838.44      838.44        0.00          0.0       organic
# 2015-01-18    11921.05    11651.09      269.96          0.0  conventional
#
#             year  region
# Date
# ...

# %%
albany_dt['Means']=albany_dt['AveragePrice'].rolling(25).mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14440\449695400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_dt['Means']=albany_dt['AveragePrice'].rolling(25).mean()

# %%
albany_dt.head(27)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
# 2015-01-18          49          1.93       1118.47     8.02    178.78    0.00
# 2015-01-25          48          1.06      45147.50   941.38  33196.16  164.14
# 2015-01-25          48          1.89       1115.89    14.87    148.72    0.00
# 2015-02-01          47          0.99      70873.60  1353.90  60017.20  179.32
# 2015-02-01          47          1.83       1228.51    33.12     99.36    0.00
# 2015-02-08          46          0.99      51253.97  1357.37  39111.81  163.25
# ...

# %%
albany_dt.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-11   0.00     2209.29     2209.29        0.00          0.0
# 2018-03-18   0.00     2580.60     2577.27        3.33          0.0
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region   Means
# Date
# 2018-03-11       organic  2018  Albany  1.4224
# ...

# %%
albany_dt.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
#
#             year  region   Means
# Date
# 2015-03-29  2015  Albany  1.4660
# 2015-03-29  2015  Albany  1.4580
# 2015-04-05  2015  Albany  1.4328

# %%
albany_dt['AveragePrice'].rolling(25).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_dt =dt.copy()[dt['region']== "Albany"]
albany_dt.set_index('Date',inplace=True)
albany_dt.sort_index(inplace=True)
albany_dt['Mean']=albany_dt['AveragePrice'].rolling(25).mean()

# %%
l1=dt['region'].unique()

# %%
graph_dt = pd.DataFrame()
for region in l1[:16]:
    print(region)
    region_dt=dt.copy()[dt['region'] == region]
    region_dt.set_index('Date',inplace=True)
    region_dt.sort_index(inplace=True)
    region_dt['Mean']=region_dt['AveragePrice'].rolling(25).mean()
    
    if graph_dt.empty:
        graph_dt=region_dt[['Mean']]
    else:
        graph_dt=graph_dt.join(region_dt['Mean'], rsuffix=f'_{region}')
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
dt.tail(3)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
graph_dt.tail()
# Out:
#               Mean  Mean_Atlanta  Mean_BaltimoreWashington  Mean_Boise  \
# Date
# 2018-03-25  1.4368        1.2884                    1.3844      1.5016
# 2018-03-25  1.4368        1.2884                    1.3844      1.5016
# 2018-03-25  1.4368        1.2884                    1.3844      1.5016
# 2018-03-25  1.4368        1.2884                    1.3844      1.5016
# 2018-03-25  1.4368        1.2884                    1.3844      1.5016
#
#             Mean_Boston  Mean_BuffaloRochester  Mean_California  \
# Date
# 2018-03-25        1.588                 1.2232           1.4232
# 2018-03-25        1.588                 1.2232           1.4232
# 2018-03-25        1.588                 1.2232           1.4232
# 2018-03-25        1.588                 1.2232           1.4232
# 2018-03-25        1.588                 1.2232           1.4232
#
#             Mean_Charlotte  Mean_Chicago  Mean_CincinnatiDayton  \
# Date
# 2018-03-25          1.4916        1.5708                 1.2792
# ...

# %%
import pandas as pd 
df=pd.read_csv("avocado.csv")
df=df.copy()[df['type']=="organic"]
dt['Date']=pd.to_datetime(df['Date'])

dt.sort_values(by="Date",ascending=True,inplace=True)
dt.head()
graph_dt = pd.DataFrame()
for region in l1[:16]:
    print(region)
    region_dt=dt.copy()[dt['region'] == region]
    region_dt.set_index('Date',inplace=True)
    region_dt.sort_index(inplace=True)
    region_dt['Mean']=region_dt['AveragePrice'].rolling(25).mean()
    
    if graph_dt.empty:
        graph_dt=region_dt[['Mean']]
    else:
        graph_dt=graph_dt.join(region_dt['Mean'], rsuffix=f'_{region}')
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
